# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests

def get_info_from_drugs_com(id1, id2):
    url = f'https://www.drugs.com/interactions-check.php?drug_list={id1},{id2}'
    opener = urllib.request.FancyURLopener({})
    f = opener.open(url)
    content = f.read()
    soup = BeautifulSoup(content, 'html.parser')

    interactions_list_info = soup.find_all('div', {"class": "interactions-reference-wrapper"})
    ## remove all inside <>
    
    return soup.prettify

# %%
def parse_items_to_ids(medicine_list, lang):
    drugs_data = pd.read_csv('medicines.csv', sep=';')
    ids = []
    # print(medicine_list, lang)
    for drug in medicine_list:
        if lang == 'en':
            ids.append(drugs_data[drugs_data["Drug_name_en"] == drug]['Id'].iloc[0])
        else:
            ids.append(drugs_data[drugs_data["Drug_name_rus"] == drug]['Id'].iloc[0])
    return ids

# %%
def processing(medicine_list, lang):

    medicine_list = list(set(medicine_list))
    medicine_list_ids = parse_items_to_ids(medicine_list, lang)

    print(get_info_from_drugs_com(medicine_list_ids[0], medicine_list_ids[1]))

# %%
med_list = ['Busulfan', 'Olaparib']
processing(med_list, 'en')
# Out:
# /tmp/ipykernel_36727/2761410374.py:9: DeprecationWarning: FancyURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   opener = urllib.request.FancyURLopener({})
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Drug Interaction Report: busulfan, olaparib</title>
# <meta content="View detailed report of drug-drug and drug-food interactions for busulfan, olaparib" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="noindex,noimageindex,max-image-preview:large" name="robots"/>
# <link href="/opensearch.xml" rel="search" title="Drugs.com" type="application/opensearchdescription+xml"/>
# <meta content="1470988726468809" property="fb:app_id"/>
# <meta content="https://www.facebook.com/Drugscom" property="article:author"/>
# ...
